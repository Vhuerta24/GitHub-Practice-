# %% [markdown]
# <a href="https://colab.research.google.com/github/Vhuerta24/GitHub-Practice-/blob/main/Data_temp_FLOAT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np                         # NumPy is an array and math library
import matplotlib.pyplot as plt            # Matplotlib is a visualization (plotting) library
import pandas as pd                        # Pandas lets us work with spreadsheet (.csv) data
from datetime import datetime, timedelta   # Datetime helps us work with dates and times

# %%
filepath_1m = '/content/temp_data_1m.csv'
filepath_2m = '/content/temp_data_2m.csv'
filepath_4m = '/content/temp_data_4m.csv'
filepath_5m = '/content/temp_data_5m.csv'
filepath_surface = '/content/temp_data_surface.csv'

# %%
data_1m = pd.read_csv(filepath_1m)
data_2m = pd.read_csv(filepath_2m)
data_4m = pd.read_csv(filepath_4m)
data_5m = pd.read_csv(filepath_5m)
data_surface = pd.read_csv(filepath_surface)

display(data_1m)
display(data_2m)
display(data_4m)
display(data_5m)
display(data_surface)
# Out:
#     8/13/2025 11:40    1  2887ca07     23.5
# 0   8/13/2025 11:50  1.0  2887ca07  23.8125
# 1   8/13/2025 11:59  1.0  2887ca07  23.8125
# 2   8/13/2025 12:09  1.0  2887ca07  23.8125
# 3   8/13/2025 12:19  1.0  2887ca07  23.8125
# 4   8/13/2025 12:29  1.0  2887ca07  23.8125
# 5   8/13/2025 12:38  1.0  2887ca07  23.8125
# 6   8/13/2025 12:48  1.0  2887ca07  23.8125
# 7   8/13/2025 12:58  1.0  2887ca07  23.8750
# 8   8/13/2025 13:08  1.0  2887ca07  23.8750
# 9   8/13/2025 13:18  1.0  2887ca07  23.8750
# 10  8/13/2025 13:27  1.0  2887ca07  23.9375
# 11  8/13/2025 13:37  1.0  2887ca07  24.0000
# 12  8/13/2025 13:47  1.0  2887ca07  24.0000
# 13  8/13/2025 13:56  1.0  2887ca07  23.9375
# 14  8/13/2025 14:06  1.0  2887ca07  24.0625
# 15  8/13/2025 14:16  1.0  2887ca07  24.0625
# 16  8/13/2025 14:26  1.0  2887ca07  24.0625
# 17  8/13/2025 14:35  1.0  2887ca07  24.0000
# 18              NaN  NaN       NaN      NaN
# 19              NaN  NaN       NaN      NaN
# ...
